# %% [markdown]
# # __FDA Food/Non-Pharmaceutical Adverse Event Reports Code Review__
#
# ## 1. Data: Uploading, converting, looking, and saving<br> 2. Outcomes Table: a LIST inside a dataframe<br> 3. Reactions Table: a LIST inside a dataframe<br> 4. Consumer Table: a DICTIONARY inside a dataframe<br> 5. Products Table: LISTS of DICTIONARIES inside a dataframe<br> 6. Postgre SQL: Creating the Database, the Tables, and Depositing the Data<br> 7. SQL Queries

# %% [markdown]
# # <font color=red>1.  DATA: Uploading, converting, looking, and saving the data</font>
# ### Food Event Reports JSON file contains ALL reports from 1 January 2004 to 31 March 2021  <br>*  https://open.fda.gov/data/downloads/  <br> * food-event-0001-of-0001.json<br> * Updated June 10th
# <font color=red> __-- a.  DATA: Import Modules__<br>__-- b. DATA: Upload food_event)data.JSON__<br>__-- c. DATA: Convert data to dataframe__<br>__-- d. DATA: Look at the dataframe__<br>__-- e. DATA: Save dataframe to CSV__</font>

# %% [markdown]
# ## <font color=blue>-- 1a. DATA: Import modules</font>

# %%
# 1a. DATA: Import modules

import json
import pandas as pd
import numpy as np
import psycopg2

# allowing Jupyter Notebook to show up to 999 rows
pd.options.display.max_rows = 999

# %% [markdown]
# ## <font color=blue>-- 1b. DATA: Upload food_event_data.JSON<font>

# %%
# 1b. DATA: Upload food_event_data.JSON

# the zipped file "food-event-0001-of-0001.json" was downloaded from the FDA website
# unzipped file was renamed "food_event_data.json"

data = json.load(open('food_event_data.json'))

# %% [markdown]
# ## <font color=blue>-- 1c. DATA: Convert data to dataframe<font>

# %%
# 1c. DATA: Convert data to dataframe

# CONVERTING the data from the "results" column, which holds the data needed, into a dataframe
food_event_df = pd.DataFrame(data["results"])

# %% [markdown]
# ## <font color=blue>-- 1d. DATA: Look at the dataframe<font>

# %%
# 1d. DATA: Look at the dataframe

# LOOKING at the dataframe 
food_event_df.head(15)

# 'outcomes' contains lists
# 'reactions' contains lists
# 'consumer' contains dictionaries
# 'products' contains dictionary of lists
# Out:
#    report_number                                           outcomes  \
# 0         100057                               [Patient Visited ER]
# 1         100529                                    [Other Outcome]
# 2         101029                                    [Other Outcome]
# 3         101096                                    [Other Outcome]
# 4         104255                                    [Other Outcome]
# 5         105456  [Life Threatening, Patient Visited Healthcare ...
# 6         105537              [Patient Visited Healthcare Provider]
# 7         106967  [Disability, Patient Visited Healthcare Provid...
# 8         107643            [Other Seriousness, Patient Visited ER]
# 9         108358                              [Medically Important]
# 10        108141                                  [Hospitalization]
# 11        109492                                    [Other Outcome]
# 12        109869                              [Medically Important]
# ...

# %% [markdown]
# ## <font color=blue>__-- 1e. DATA: Save dataframe to CSV__<font>

# %%
# 1e. DATA: Save dataframe to CSV

# SAVING dataframe to CSV file
food_event_df.to_csv(r'food_event_dataframe.csv', index = False)

# %% [markdown]
# # <font color=red>2. OUTCOMES TABLE: a LIST inside a dataframe</font>
# ## <div class="alert alert-block alert-success"> pandas.dataframe.explode() -- a method for extracting lists, giving each value a new row, while duplicating the other columns into the new row</div>
# <font color=red>__-- a.  OUTCOMES: Create dataframe with 'report_number' and 'outcomes'__<br>__-- b. OUTCOMES: Use dataframe.explode() method to extract 'outcomes' values__<br>__-- c. OUTCOMES: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies__<br>__-- d. OUTCOMES: Save outcomes_table to CSV__</font>

# %% [markdown]
# ## <font color=blue>-- 2a. OUTCOMES: Create dataframe with 'report_number' and 'outcomes'</font>

# %%
# 2a. OUTCOMES: Create dataframe with 'report_number' and 'outcomes'

# Create an OUTCOMES dataframe using 'report_number' and 'outcomes' columns from the main dataframe
outcomes_df = food_event_df[["report_number","outcomes"]]

outcomes_df.head(15)
# Out:
#    report_number                                           outcomes
# 0         100057                               [Patient Visited ER]
# 1         100529                                    [Other Outcome]
# 2         101029                                    [Other Outcome]
# 3         101096                                    [Other Outcome]
# 4         104255                                    [Other Outcome]
# 5         105456  [Life Threatening, Patient Visited Healthcare ...
# 6         105537              [Patient Visited Healthcare Provider]
# 7         106967  [Disability, Patient Visited Healthcare Provid...
# 8         107643            [Other Seriousness, Patient Visited ER]
# 9         108358                              [Medically Important]
# 10        108141                                  [Hospitalization]
# 11        109492                                    [Other Outcome]
# 12        109869                              [Medically Important]
# ...

# %% [markdown]
# ## <font color=blue>-- 2b. OUTCOMES: Use dataframe.explode() method to extract 'outcomes' values</font>

# %%
# 2b. OUTCOMES: Use dataframe.explode() method to extract 'outcomes' values

# use DATAFRAME.EXPLODE() method to open up the lists so each value has one row paired with its report_number
outcomes_table = outcomes_df.explode("outcomes")

outcomes_table.head(15)
# Out:
#   report_number                             outcomes
# 0        100057                   Patient Visited ER
# 1        100529                        Other Outcome
# 2        101029                        Other Outcome
# 3        101096                        Other Outcome
# 4        104255                        Other Outcome
# 5        105456                     Life Threatening
# 5        105456  Patient Visited Healthcare Provider
# 5        105456                   Patient Visited ER
# 5        105456                Required Intervention
# 6        105537  Patient Visited Healthcare Provider
# 7        106967                           Disability
# 7        106967  Patient Visited Healthcare Provider
# 7        106967                    Other Seriousness
# 8        107643                    Other Seriousness
# 8        107643                   Patient Visited ER

# %% [markdown]
# ## <font color=blue>-- 2c. OUTCOMES: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies</font>

# %%
# 2c. OUTCOMES: Look at total value counts, unique value counts, and counts of values to check for any obvious 
#               inconsistencies

print("TOTAL OUTCOMES = ", outcomes_table['outcomes'].value_counts().sum())
print("TOTAL UNIQUE OUTCOMES = ", outcomes_table['outcomes'].nunique())
print(outcomes_table['outcomes'].value_counts())

# no obvious inconsistencies found
# Out:
# TOTAL OUTCOMES =  121981
# TOTAL UNIQUE OUTCOMES =  11
# Medically Important                    39017
# Other Outcome                          23528
# Patient Visited Healthcare Provider    17442
# Hospitalization                        12223
# Patient Visited ER                     10468
# Death                                   6027
# Other Seriousness                       4518
# Life Threatening                        4178
# Disability                              2496
# Required Intervention                   2012
# Congenital Anomaly                        72
# Name: outcomes, dtype: int64

# %% [markdown]
# ## <font color=blue>-- 2d. OUTCOMES: Save outcomes_table to CSV</font>

# %%
# Save the Outcomes table to a CSV file
outcomes_table.to_csv(r'outcomes_table.csv', index = False)

# %% [markdown]
# # <font color=red>3. REACTIONS TABLE: a LIST inside a dataframe</font>
# ## <div class="alert alert-block alert-success"> pandas.dataframe.explode() -- a method for extracting lists, giving each value a new row, while duplicating the other columns into the new row </div>
# <font color=red>__-- a. REACTIONS: Create dataframe with 'report_number' and 'reactions'__<br>__-- b. REACTIONS: Use dataframe.explode() method to extract 'reactions' values__<br>__-- c. REACTIONS: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies__<br>__-- d. REACTIONS: Checking for Case format - Outcomes are a mixed case format (Upper-lower), with Reactions countering by a full Upper-case format (which helps with column differentiation; Death in OUTCOMES, as opposed to DEATH in REACTIONS)__<br>__-- e. REACTIONS: Change all values in 'reactions' to Upper Case__<br>__-- f. REACTIONS: Save reactions_table to CSV__</font>

# %% [markdown]
# ## <font color=blue>-- 3a. REACTIONS: Create dataframe with 'report_number' and 'reactions'</font>

# %%
# 3a. REACTIONS: Create dataframe with 'report_number' and 'reactions'

# Create a REACTIONS dataframe using 'report_number' and 'reactions' columns from the main dataframe
reactions_df = food_event_df[["report_number","reactions"]]

reactions_df.head()
# Out:
#   report_number                                          reactions
# 0        100057  [SALIVARY HYPERSECRETION, NAUSEA, ABDOMINAL PAIN]
# 1        100529                   [SYNCOPE, NAUSEA, HYPERHIDROSIS]
# 2        101029                   [VOMITING, ABDOMINAL DISCOMFORT]
# 3        101096                                          [MALAISE]
# 4        104255                                         [VOMITING]

# %% [markdown]
# ## <font color=blue>-- 3b. REACTIONS: Use dataframe.explode() method to extract 'reactions' values</font>

# %%
# 3b. REACTIONS: Use dataframe.explode() method to extract 'reactions' values

# use DATAFRAME.EXPLODE() method to open up the lists so each value has one row paired with its report_number
reactions_table = reactions_df.explode("reactions")

reactions_table.head(15)
# Out:
#   report_number                reactions
# 0        100057  SALIVARY HYPERSECRETION
# 0        100057                   NAUSEA
# 0        100057           ABDOMINAL PAIN
# 1        100529                  SYNCOPE
# 1        100529                   NAUSEA
# 1        100529            HYPERHIDROSIS
# 2        101029                 VOMITING
# 2        101029     ABDOMINAL DISCOMFORT
# 3        101096                  MALAISE
# 4        104255                 VOMITING
# 5        105456             PARAESTHESIA
# 5        105456    LOSS OF CONSCIOUSNESS
# 5        105456      HEART RATE ABNORMAL
# 5        105456      DYSPNOEA EXERTIONAL
# 5        105456       ANAPHYLACTIC SHOCK

# %% [markdown]
# ## <font color=blue>-- 3c. REACTIONS: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies</font>

# %%
# 3c. REACTIONS: Look at total value counts, unique value counts, and counts of values to check for any obvious 
#                inconsistencies

print("TOTAL REACTIONS = ", reactions_table['reactions'].value_counts().sum())
print("TOTAL UNIQUE REACTIONS = ", reactions_table['reactions'].nunique())
print(reactions_table['reactions'].value_counts())

# no obvious inconsistencies found
# Out:
# TOTAL REACTIONS =  265379
# TOTAL UNIQUE REACTIONS =  4708
# DIARRHOEA                 13933
# VOMITING                  11830
# OVARIAN CANCER            11719
# NAUSEA                    10012
# ABDOMINAL PAIN             7845
#                           ...
# PLACENTAL DISORDER            1
# FLUID REPLACEMENT             1
# Feeling abnormal              1
# AORTIC VALVE SCLEROSIS        1
# HERPES OPHTHALMIC             1
# Name: reactions, Length: 4708, dtype: int64

# %% [markdown]
# ## <font color=blue>-- 3d. REACTIONS: Checking for Case format - Outcomes are a mixed case format (Upper-lower), with Reactions countering by a full Upper-case format (which helps with column differentiation; Death in OUTCOMES, as opposed to DEATH in REACTIONS) </font>

# %%
# 3d. REACTIONS: Checking for Case format - Outcomes are a mixed case format (Upper-lower), with Reactions countering 
#                by a full Upper-case format (which helps with column differentiation; Death in OUTCOMES, as opposed 
#                to DEATH in REACTIONS)

# Checking for values with lower-cased letters
# This is not just for visual consistency, but also to prevent any errors if analysis is case-sensitive
# It also shows that the reporter is typing this in by hand 

lowercase_react = []

for x in reactions_table['reactions']:
    x = str(x)
    if x.isupper() == False:
        lowercase_react.append(x)
        
for y in lowercase_react:
    if y != 'nan':
        print(y)

# lower case confirmed
# Out:
# Anxiety
# Dysphagia
# Apparent death
# Weight decreased
# Muscle twitching
# Functional gastrointestinal disorder
# Electrolyte imbalance
# Constipation
# Blood phosphorus decreased
# Apparent death
# Abdominal pain upper
# Abdominal discomfort
# Macular degeneration
# Hypertension
# Heart rate increased
# Heart rate abnormal
# Blood pressure increased
# Blindness unilateral
# Asthenia
# Apparent death
# Dysphagia
# Apparent death
# Thyroid disorder
# Sluggishness
# Pain in jaw
# Hyperhidrosis
# Fatigue
# Dyspnoea
# Blood pressure increased
# Asthenia
# Angina pectoris
# Alopecia
# Throat irritation
# Oropharyngeal pain
# Musculoskeletal chest pain
# Foreign body
# Choking
# Foreign body
# Apparent death
# Cough
# Choking
# Apparent death
# Ventricular fibrillation
# Troponin I increased
# Myocardial infarction
# Hypokinesia
# Cardiac arrest
# Arteriospasm coronary
# Arterial spasm
# Apparent death
# Headache
# Apparent death
# Foreign body
# Dyspnoea
# Choking
# Apparent death
# ...

# %% [markdown]
# ## <font color=blue>-- 3e. REACTIONS: Change all values in 'reactions' to Upper Case</font>

# %%
# 3e. REACTIONS: Change all values in 'reactions' to Upper Case

# Changing all the values in reactions to upper case
reactions_table['reactions']= reactions_table['reactions'].str.upper()

# %% [markdown]
# ## <font color=blue>-- 3f. REACTIONS: Save reactions_table to CSV</font>

# %%
# 3f. REACTIONS: Save reactions_table to CSV

# Save the Reactions table to a CSV file
reactions_table.to_csv(r'reactions_table.csv', index = False)

# %% [markdown]
# # <font color=red>4. CONSUMER TABLE: a DICTIONARY inside a dataframe</font>
# ## <div class="alert alert-block alert-success"> pandas.dataframe.apply(pd.Series) -- is a method used to change the shape of the dictionary, extracting it into columns</div>
# <font color=red>__-- a. CONSUMER: Create dataframe with 'report_number' and 'consumer'__<br>__-- b. CONSUMER: Use dataframe.apply(pd.Series) method to extract 'consumer' values of 'age', 'age_unit', and 'gender'__<br>__-- c. CONSUMER: Add 'report_number', 'date_created', 'date_started'__<br>__-- d. CONSUMER: Reorder and rename columns__<br>__-- e. CONSUMER - CONSUMER_AGE: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies__<br>__-- f. CONSUMER - AGE_UNIT: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies__<br>__-- g. CONSUMER - CONSUMER_GENDER: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies__ <br>__-- h. CONSUMER - CONSUMER_GENDER: Remove NR and U values (count = 2)__ <br>__-- i. CONSUMER: Add 'age_unit_calc' column for calculating the consumer's age__<br>__-- j. CONSUMER: Add column with the actual age of the consumer__<br>__-- k. CONSUMER: Save dataframe to CSV__</font>

# %% [markdown]
# ## <font color=blue>-- 4a. CONSUMER: Create dataframe with 'report_number' and 'consumer'</font>

# %%
# 4a. CONSUMER: Create dataframe with 'report_number' and 'consumer'

# Create a consumer dataframe using 'report_number' and 'consumer' columns from the main dataframe
consumer_df = food_event_df[["report_number","consumer"]]

consumer_df.head(15)
# Out:
#    report_number                                           consumer
# 0         100057                                                 {}
# 1         100529                                                 {}
# 2         101029                                                 {}
# 3         101096  {'age': '21', 'age_unit': 'year(s)', 'gender':...
# 4         104255                                                 {}
# 5         105456  {'age': '56', 'age_unit': 'year(s)', 'gender':...
# 6         105537               {'age': '13', 'age_unit': 'year(s)'}
# 7         106967  {'age': '44', 'age_unit': 'year(s)', 'gender':...
# 8         107643  {'age': '26', 'age_unit': 'year(s)', 'gender':...
# 9         108358  {'age': '56', 'age_unit': 'year(s)', 'gender':...
# 10        108141  {'age': '13', 'age_unit': 'year(s)', 'gender':...
# 11        109492  {'age': '61', 'age_unit': 'year(s)', 'gender':...
# 12        109869                                                 {}
# ...

# %% [markdown]
# ## <font color=blue>-- 4b. CONSUMER: Use dataframe.apply(pd.Series) method to extract 'consumer' values of 'age', 'age_unit', and 'gender'</font>

# %%
# 4b. CONSUMER: Use dataframe.apply(pd.Series) method to extract 'consumer' values of 'age', 'age_unit', and 'gender'

# Use dataframe.apply(pd.Series) to re-shape the consumer column <-- this takes a couple of minutes
#  This breaks the consumer column out into 'age', 'age_unit', and 'gender' 
consumer_reshape = consumer_df.consumer.apply(pd.Series)

consumer_reshape.head(15)
# Out:
#     age age_unit gender
# 0   NaN      NaN    NaN
# 1   NaN      NaN    NaN
# 2   NaN      NaN    NaN
# 3    21  year(s)      M
# 4   NaN      NaN    NaN
# 5    56  year(s)      F
# 6    13  year(s)    NaN
# 7    44  year(s)      M
# 8    26  year(s)      M
# 9    56  year(s)      M
# 10   13  year(s)      M
# 11   61  year(s)      F
# 12  NaN      NaN    NaN
# 13   53  year(s)      M
# 14  NaN      NaN    NaN

# %% [markdown]
# ## <font color=blue>-- 4c. CONSUMER: Add 'report_number', 'date_created', 'date_started'</font>

# %%
# 4c. CONSUMER: Add 'report_number', 'date_created', 'date_started'

# Add 'report_number', 'date_created' and 'date_started' from food_event_df
dates = food_event_df[["report_number","date_created","date_started"]]
consumer_added = consumer_reshape.join(dates)

consumer_added.head()
# Out:
#    age age_unit gender report_number date_created date_started
# 0  NaN      NaN    NaN        100057     20080201     20071116
# 1  NaN      NaN    NaN        100529     20080220         None
# 2  NaN      NaN    NaN        101029     20080306         None
# 3   21  year(s)      M        101096     20080310     20080210
# 4  NaN      NaN    NaN        104255     20080625     20080405

# %% [markdown]
# ## <font color=blue>-- 4d. CONSUMER: Reorder and rename columns</font>

# %%
# 4d. CONSUMER: Reorder and rename columns

# Reordering the columns so report_number is in the first position
consumer_table = consumer_added[["report_number", "age", "age_unit", "gender", "date_created", "date_started"]]

# Renaming the age and gender columns to something more descriptive
consumer_table = consumer_table.rename(columns = {'age': 'consumer_age', 
                                                        'gender': 'consumer_gender'}, inplace = False)

consumer_table.head()
# Out:
#   report_number consumer_age age_unit consumer_gender date_created  \
# 0        100057          NaN      NaN             NaN     20080201
# 1        100529          NaN      NaN             NaN     20080220
# 2        101029          NaN      NaN             NaN     20080306
# 3        101096           21  year(s)               M     20080310
# 4        104255          NaN      NaN             NaN     20080625
#
#   date_started
# 0     20071116
# 1         None
# 2         None
# 3     20080210
# 4     20080405

# %% [markdown]
# ## <font color=blue>-- 4e. CONSUMER - CONSUMER_AGE: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies</font>

# %%
# 4e. CONSUMER - CONSUMER_AGE: Look at total value counts, unique value counts, and counts of values to check for any 
#                obvious inconsistencies

print("TOTAL CONSUMER AGES REPORTED = ", consumer_table['consumer_age'].value_counts().sum())
print("TOTAL UNIQUE CONSUMER AGES REPORTED = ", consumer_table['consumer_age'].nunique())
print(consumer_table['consumer_age'].value_counts().sort_index())

# no obvious inconsistencies found
# Out:
# TOTAL CONSUMER AGES REPORTED =  47847
# TOTAL UNIQUE CONSUMER AGES REPORTED =  107
# 0       11
# 1      192
# 10     267
# 100      6
# 101      3
#       ...
# 95      43
# 96      28
# 97      28
# 98      15
# 99      11
# Name: consumer_age, Length: 107, dtype: int64

# %% [markdown]
# ## <font color=blue>-- 4f. CONSUMER - AGE_UNIT: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies</font>

# %%
# 4f. CONSUMER - AGE_UNIT: Look at total value counts, unique value counts, and counts of values to check for any 
#                obvious inconsistencies

print("TOTAL AGE_UNITS REPORTED = ", consumer_table['age_unit'].value_counts().sum())
print("TOTAL UNIQUE AGE_UNITS REPORTED = ", consumer_table['age_unit'].nunique())
print(consumer_table['age_unit'].value_counts().sort_index())

# Decade(s) will remain as it is due to the 'D' differing between day and Decade
# Out:
# TOTAL AGE_UNITS REPORTED =  47946
# TOTAL UNIQUE AGE_UNITS REPORTED =  5
# Decade(s)       26
# day(s)         138
# month(s)      1276
# week(s)         62
# year(s)      46444
# Name: age_unit, dtype: int64

# %% [markdown]
# ## <font color=blue>-- 4g. CONSUMER - CONSUMER_GENDER: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies</font>

# %%
#  4g. CONSUMER - CONSUMER_GENDER: Look at total value counts, unique value counts, and counts of values to check for any 
#                 obvious inconsistencies

print("TOTAL CONSUMER_GENDERS = ", consumer_table['consumer_gender'].value_counts().sum())
print("TOTAL UNIQUE CONSUMER_GENDERS REPORTED = ", consumer_table['consumer_gender'].nunique())
print(consumer_table['consumer_gender'].value_counts().sort_index())

# The NR and U need to be rectified - turn to Nan
# Out:
# TOTAL CONSUMER_GENDERS =  46805
# TOTAL UNIQUE CONSUMER_GENDERS REPORTED =  4
# F     32424
# M     14379
# NR        1
# U         1
# Name: consumer_gender, dtype: int64

# %% [markdown]
# ## <font color=blue>-- 4h. CONSUMER - CONSUMER_GENDER: Remove NR and U values (count = 2) </font>

# %%
# 4h. CONSUMER - CONSUMER_GENDER: Remove NR and U values (count = 2)

consumer_table.drop(consumer_table.index[consumer_table['consumer_gender'] == 'U'], inplace = True) 
consumer_table.drop(consumer_table.index[consumer_table['consumer_gender'] == 'NR'], inplace = True) 

print(consumer_table['consumer_gender'].value_counts().sort_index())
# Out:
# F    32424
# M    14379
# Name: consumer_gender, dtype: int64

# %% [markdown]
# ##  <font color=blue>-- 4i. CONSUMER: Add 'age_unit_calc' column for calculating the consumer's age</font>

# %%
# 4i. CONSUMER: Add 'age_unit_calc' column for calculating the consumer's age

# Adding calculation column based on portion of year

# create a list of conditions
conditions = [
    (consumer_table['age_unit'] == "day(s)"),
    (consumer_table['age_unit'] == "week(s)"),
    (consumer_table['age_unit'] == "months(s)"),
    (consumer_table['age_unit'] == "year(s)"),
    (consumer_table['age_unit'] == "Decade(s)")
    ]

# create a list of the values for each condition
values = [0.0027, 0.0192, 0.0833, 1, 10]

# create a new column and use np.select to assign values using lists as arguments
consumer_table['age_unit_calc'] = np.select(conditions, values)

# display value count to get full numeric value
consumer_table['age_unit_calc'].value_counts()
# Out:
# 1.0000     46442
# 0.0000     45106
# 0.0027       138
# 0.0192        62
# 10.0000       26
# Name: age_unit_calc, dtype: int64

# %% [markdown]
# ## <font color=blue>-- 4j. CONSUMER: Add column with the actual age of the consumer <font>

# %%
# 4j. CONSUMER: Add column with the actual age of the consumer

# turn consumer_age NaN into numerical value 
consumer_table['consumer_age'] = consumer_table['consumer_age'].fillna(0)

# calculate the consumer's true age
consumer_table['absolute_age'] = consumer_table.consumer_age.astype(float)* consumer_table.age_unit_calc 

consumer_table.head()
# Out:
#   report_number consumer_age age_unit consumer_gender date_created  \
# 0        100057            0      NaN             NaN     20080201
# 1        100529            0      NaN             NaN     20080220
# 2        101029            0      NaN             NaN     20080306
# 3        101096           21  year(s)               M     20080310
# 4        104255            0      NaN             NaN     20080625
#
#   date_started  age_unit_calc  absolute_age
# 0     20071116            0.0           0.0
# 1         None            0.0           0.0
# 2         None            0.0           0.0
# 3     20080210            1.0          21.0
# 4     20080405            0.0           0.0

# %% [markdown]
# ## <font color=blue>__-- 4k. CONSUMER: Save dataframe to CSV__<font>

# %%
# 4k. CONSUMER: Save dataframe to CSV

# Save the Consumer Info and Dates table to a CSV file
consumer_table.to_csv(r'consumer_report_table.csv', index = False)

# %% [markdown]
# # <font color=red>5.  PRODUCTS TABLE: LISTS of DICTIONARIES inside a dataframe</font>
# ## <div class="alert alert-block alert-success">pandas.dataframe.explode()<br> pandas.dataframe.apply(pd.Series)</div> <br>Explode Method to expand the LISTS of DICTIONARIES<br>pd.Series used to change the shape of the DICTIONARY<br> -- Applied to "Products"
# <font color=red>__-- a. PRODUCTS: Create dataframe using 'report_number' and 'products'__<br>__-- b. PRODUCTS: Use dataframe.explode() method to extract 'products' values__<br>__-- c. PRODUCTS: Use dataframe.apply(pd.Series) method to extract 'products' values of 'role', 'name_brand','industry_code', and 'industry_name'__<br>__-- d. PRODUCTS: Reattach 'report number' to product dataframe__<br>__-- e. PRODUCTS: Remove duplicate rows__<br>__-- f. PRODUCTS: Change 'name_brand' to all upper case__<br>__-- g. PRODUCTS: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies__ <br>__-- h. PRODUCTS: Quick post-changes visual check__ <br>__-- i. PRODUCTS: Re-ording columns__<br>__-- j. PRODUCTS: Save dataframe to CSV__</font>

# %% [markdown]
# ## <font color=blue>-- 5a. PRODUCTS: Create dataframe using 'report_number' and 'products'</font>

# %%
# 5a. PRODUCTS: Create dataframe using 'report_number' and 'products'

# Create a products dataframe using REPORT_NUMBER and PRODUCTS columns from the main dataframe
products_df = food_event_df[["report_number","products"]]

products_df.head(15)
# Out:
#    report_number                                           products
# 0         100057  [{'role': 'SUSPECT', 'name_brand': 'DASANI BOT...
# 1         100529  [{'role': 'SUSPECT', 'name_brand': 'SPLENDA SU...
# 2         101029  [{'role': 'SUSPECT', 'name_brand': 'LAND O'LAK...
# 3         101096  [{'role': 'SUSPECT', 'name_brand': 'WELCH'S GR...
# 4         104255  [{'role': 'SUSPECT', 'name_brand': 'EL MONTERE...
# 5         105456  [{'role': 'SUSPECT', 'name_brand': 'ISAGENIX I...
# 6         105537  [{'role': 'SUSPECT', 'name_brand': 'HERSHEYS S...
# 7         106967  [{'role': 'SUSPECT', 'name_brand': 'CENTRUM CA...
# 8         107643  [{'role': 'SUSPECT', 'name_brand': 'SUPER STIN...
# 9         108358  [{'role': 'SUSPECT', 'name_brand': 'TAZO ORGAN...
# 10        108141  [{'role': 'SUSPECT', 'name_brand': 'SIMILAC AD...
# 11        109492  [{'role': 'SUSPECT', 'name_brand': 'KELLOGG'S ...
# 12        109869  [{'role': 'CONCOMITANT', 'name_brand': 'CHOLES...
# ...

# %% [markdown]
# ## <font color=blue>-- 5b. PRODUCTS: Use dataframe.explode() method to extract 'products' values</font>

# %%
# 5b. PRODUCTS: Use dataframe.explode() method to extract 'products' values

products_explode = products_df.explode("products")

products_explode.head(20)
# Out:
#    report_number                                           products
# 0         100057  {'role': 'SUSPECT', 'name_brand': 'DASANI BOTT...
# 1         100529  {'role': 'SUSPECT', 'name_brand': 'SPLENDA SUC...
# 2         101029  {'role': 'SUSPECT', 'name_brand': 'LAND O'LAKE...
# 3         101096  {'role': 'SUSPECT', 'name_brand': 'WELCH'S GRA...
# 4         104255  {'role': 'SUSPECT', 'name_brand': 'EL MONTEREY...
# 5         105456  {'role': 'SUSPECT', 'name_brand': 'ISAGENIX IO...
# 6         105537  {'role': 'SUSPECT', 'name_brand': 'HERSHEYS SY...
# 7         106967  {'role': 'SUSPECT', 'name_brand': 'CENTRUM CAR...
# 8         107643  {'role': 'SUSPECT', 'name_brand': 'SUPER STING...
# 9         108358  {'role': 'SUSPECT', 'name_brand': 'TAZO ORGANI...
# 10        108141  {'role': 'SUSPECT', 'name_brand': 'SIMILAC ADV...
# 11        109492  {'role': 'SUSPECT', 'name_brand': 'KELLOGG'S K...
# 12        109869  {'role': 'CONCOMITANT', 'name_brand': 'CHOLEST...
# ...

# %% [markdown]
# ## <font color=blue>-- 5c. PRODUCTS: Use dataframe.apply(pd.Series) method to extract 'products' values of 'role', 'name_brand','industry_code', and 'industry_name'</font>

# %%
# 5c. PRODUCTS: Use dataframe.apply(pd.Series) method to extract 'products' values of 'role', 'name_brand',
#              'industry_code', and 'industry_name'

# Extract the values from the dictionaries - this takes awhile due to data size
products_extract = products_explode.products.apply(pd.Series)

products_extract.head(15)
# Out:
#            role                                         name_brand  \
# 0       SUSPECT                               DASANI BOTTLED WATER
# 1       SUSPECT                            SPLENDA SUCRALOSE SUGAR
# 2       SUSPECT                LAND O'LAKES FAT FREE HALF AND HALF
# 3       SUSPECT                                WELCH'S GRAPE JUICE
# 4       SUSPECT      EL MONTEREY BEEF AND BEAN GREEN CHILI BURRITO
# 5       SUSPECT                             ISAGENIX IOMIC SUPREME
# 6       SUSPECT  HERSHEYS SYMPHONY BAR CREAMY MILK ALMOND AND T...
# 7       SUSPECT  CENTRUM CARDIO MULTIVITAMIN MULTIMINERAL SUPPL...
# 8       SUSPECT                              SUPER STINGERS 4 CAPS
# 9       SUSPECT                              TAZO ORGANIC CHAI TEA
# 10      SUSPECT          SIMILAC ADVANCED SOY FORMULA WITH DHA ARA
# 11      SUSPECT           KELLOGG'S KEEBLER PEANUT BUTTER CRACKERS
# 12  CONCOMITANT                                        CHOLEST OFF
# ...

# %% [markdown]
# ## <font color=blue>-- 5d. PRODUCTS: Reattach 'report number' to product dataframe </font>

# %%
# 5d. PRODUCTS: Reattach 'report number' to product datafram

# Reattach the report number to the product dataframe
products_number = products_extract.join(products_explode["report_number"])

products_number.head(25)
# Out:
#            role                                         name_brand  \
# 0       SUSPECT                               DASANI BOTTLED WATER
# 1       SUSPECT                            SPLENDA SUCRALOSE SUGAR
# 2       SUSPECT                LAND O'LAKES FAT FREE HALF AND HALF
# 3       SUSPECT                                WELCH'S GRAPE JUICE
# 4       SUSPECT      EL MONTEREY BEEF AND BEAN GREEN CHILI BURRITO
# 5       SUSPECT                             ISAGENIX IOMIC SUPREME
# 6       SUSPECT  HERSHEYS SYMPHONY BAR CREAMY MILK ALMOND AND T...
# 7       SUSPECT  CENTRUM CARDIO MULTIVITAMIN MULTIMINERAL SUPPL...
# 8       SUSPECT                              SUPER STINGERS 4 CAPS
# 9       SUSPECT                              TAZO ORGANIC CHAI TEA
# 10      SUSPECT          SIMILAC ADVANCED SOY FORMULA WITH DHA ARA
# 11      SUSPECT           KELLOGG'S KEEBLER PEANUT BUTTER CRACKERS
# 12  CONCOMITANT                                        CHOLEST OFF
# ...

# %% [markdown]
# ## <font color=blue>-- 5e. PRODUCTS: Remove duplicate rows </font>

# %%
# 5e. PRODUCTS: Remove duplicate rows

products_number = products_number.drop_duplicates()

# %% [markdown]
# ## <font color=blue>-- 5f. PRODUCTS: Change 'name_brand' to all upper case </font>

# %%
# 5f. PRODUCTS: Change 'name_brand' to all upper case 

# Changing all the values in reactions to upper case
products_number['name_brand']= products_number['name_brand'].str.upper()

products_number.head()
# Out:
#       role                                     name_brand industry_code  \
# 0  SUSPECT                           DASANI BOTTLED WATER            29
# 1  SUSPECT                        SPLENDA SUCRALOSE SUGAR            36
# 2  SUSPECT            LAND O'LAKES FAT FREE HALF AND HALF             9
# 3  SUSPECT                            WELCH'S GRAPE JUICE            20
# 4  SUSPECT  EL MONTEREY BEEF AND BEAN GREEN CHILI BURRITO            37
#
#                          industry_name report_number
# 0                     Soft Drink/Water        100057
# 1          Food Sweeteners (Nutritive)        100529
# 2          Milk/Butter/Dried Milk Prod        101029
# 3                     Fruit/Fruit Prod        101096
# 4  Mult Food Dinner/Grav/Sauce/Special        104255

# %% [markdown]
# ## <font color=blue>-- 5g. PRODUCTS: Look at total value counts, unique value counts, and counts of values to check for any obvious inconsistencies </font>

# %%
# 5g. PRODUCTS: Look at total value counts, unique value counts, and counts of values to check for any 
#               obvious inconsistencies

print("TOTAL PRODUCTS = ", products_number['name_brand'].value_counts().sum())
print("TOTAL UNIQUE PRODUCTS = ", products_number['name_brand'].nunique())
print(products_number['name_brand'].value_counts())

# no obvious inconsistencies found
# Out:
# TOTAL PRODUCTS =  130805
# TOTAL UNIQUE PRODUCTS =  57554
# EXEMPTION 4                                         19296
# VITAMIN D                                            1182
# SUPER BETA PROSTATE                                  1109
# MULTIVITAMIN                                          939
# FISH OIL                                              889
#                                                     ...
# VITAMIN B STRESS COMPLEX                                1
# BILEMIN-K-11                                            1
# PRAIRIE FARMS HEAVY WHIPPING CREAM                      1
# NATURE'S SECRET MULTI FIBER DIETARY SUPPLEMENT          1
# CALCIUM MAGNESIUM CITRATE WITH VITAMIN D3 LIQUID        1
# Name: name_brand, Length: 57554, dtype: int64

# %% [markdown]
# ## <font color=blue>-- 5h. PRODUCTS: Quick post-changes visual check </font>

# %%
# 5h. PRODUCTS: Quick post-changes visual check

products_number.head(25)
# Out:
#            role                                         name_brand  \
# 0       SUSPECT                               DASANI BOTTLED WATER
# 1       SUSPECT                            SPLENDA SUCRALOSE SUGAR
# 2       SUSPECT                LAND O'LAKES FAT FREE HALF AND HALF
# 3       SUSPECT                                WELCH'S GRAPE JUICE
# 4       SUSPECT      EL MONTEREY BEEF AND BEAN GREEN CHILI BURRITO
# 5       SUSPECT                             ISAGENIX IOMIC SUPREME
# 6       SUSPECT  HERSHEYS SYMPHONY BAR CREAMY MILK ALMOND AND T...
# 7       SUSPECT  CENTRUM CARDIO MULTIVITAMIN MULTIMINERAL SUPPL...
# 8       SUSPECT                              SUPER STINGERS 4 CAPS
# 9       SUSPECT                              TAZO ORGANIC CHAI TEA
# 10      SUSPECT          SIMILAC ADVANCED SOY FORMULA WITH DHA ARA
# 11      SUSPECT           KELLOGG'S KEEBLER PEANUT BUTTER CRACKERS
# 12  CONCOMITANT                                        CHOLEST OFF
# ...

# %% [markdown]
# ## <font color=blue>-- 5i. PRODUCTS: Re-ording columns </font>

# %%
# 5i. PRODUCTS: Re-ording columns

# Reordering the columns so report_number is in the first position
products_table = products_number[["report_number", "role", "name_brand", "industry_code", "industry_name"]]
products_table.head()
# Out:
#   report_number     role                                     name_brand  \
# 0        100057  SUSPECT                           DASANI BOTTLED WATER
# 1        100529  SUSPECT                        SPLENDA SUCRALOSE SUGAR
# 2        101029  SUSPECT            LAND O'LAKES FAT FREE HALF AND HALF
# 3        101096  SUSPECT                            WELCH'S GRAPE JUICE
# 4        104255  SUSPECT  EL MONTEREY BEEF AND BEAN GREEN CHILI BURRITO
#
#   industry_code                        industry_name
# 0            29                     Soft Drink/Water
# 1            36          Food Sweeteners (Nutritive)
# 2             9          Milk/Butter/Dried Milk Prod
# 3            20                     Fruit/Fruit Prod
# 4            37  Mult Food Dinner/Grav/Sauce/Special

# %% [markdown]
# ## <font color=blue>-- 5j. PRODUCTS: Save dataframe to CSV </font>

# %%
# 5j. PRODUCTS: Save dataframe to CSV

# Save the Consumer Info and Dates table to a CSV file
products_table.to_csv(r'products_table.csv', index = False)

# %% [markdown]
# # <font color=red>6. Postgre SQL - Creating the Database, the Tables, and Depositing the Data</font>
# <font color=red>__-- a. Postgre SQL: Database creation - "fda_food_events"__<br>__-- b.Postgre SQL: Table creation - "outcomes"__<br>__-- c. Postgre SQL: Table creation - "reactions"__<br>__-- d. Postgre SQL: Table creation - "consumer_report"__<br>__-- e. Postgre SQL: Table creation - "products"__<br>__-- f. Postgre SQL: Data deposit - "outcomes" table__<br>__-- g. Postgre SQL: Data deposit - "reactions" table__ <br>__-- h. Postgre SQL: Data deposit - "consumer_report" table__<br>__-- i. Postgre SQL: Data deposit - "products" table__

# %% [markdown]
# ## <font color=blue>-- 6a. Postgre SQL: Database creation - "fda_food_events"</font>

# %%
# 6a. Postgre SQL: Create the database "fda_food_events

from psycopg2 import connect
import sys
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

con = None
con = connect("host=localhost user=postgres password = Liam2007!")

dbname = "fda_food_events"

con.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
cur = con.cursor()
cur.execute('CREATE DATABASE ' + dbname)
cur.close()
con.close()

# %% [markdown]
# ## <font color=blue>-- 6b. Postgre SQL: Table creation - "outcomes"</font>

# %%
# 6b. Postgre SQL: Create the Outcomes table

conn = psycopg2.connect("host=localhost dbname=fda_food_events user=postgres password = Liam2007!")
cur = conn.cursor()
cur.execute("""CREATE TABLE public.outcomes
(
    report_number character varying(255) COLLATE pg_catalog."default",
    outcome character varying(255) COLLATE pg_catalog."default"
)
""")
conn.commit()

# %% [markdown]
# ## <font color=blue>-- 6c. Postgre SQL: Table creation - "reactions"</font>

# %%
# 6c. Postgre SQL: Create the Reactions table

conn = psycopg2.connect("host=localhost dbname=fda_food_events user=postgres password = Liam2007!")
cur = conn.cursor()
cur.execute("""CREATE TABLE public.reactions
(
    report_number character varying(255) COLLATE pg_catalog."default",
    reaction character varying(255) COLLATE pg_catalog."default"
)
""")
conn.commit()

# %% [markdown]
# ## <font color=blue>-- 6d. Postgre SQL: Table creation - "consumer_report"</font>

# %%
# 6d. SQL: Create the Consumer Report table

conn = psycopg2.connect("host=localhost dbname=fda_food_events user=postgres password = Liam2007!")
cur = conn.cursor()
cur.execute("""CREATE TABLE public.consumer_report
(
    report_number character varying(255) COLLATE pg_catalog."default",
    consumer_age integer,
    age_unit character varying(255) COLLATE pg_catalog."default",
    consumer_gender character varying(255) COLLATE pg_catalog."default",
    date_created date,
    date_started date,
    age_conv_to_year numeric,
    absolute_age numeric
)
""")
conn.commit()

# %% [markdown]
# ## <font color=blue>-- 6e. Postgre SQL: Table creation - "products"</font>

# %%
# 6e. Postgre SQL: Create Products table

conn = psycopg2.connect("host=localhost dbname=fda_food_events user=postgres password = Liam2007!")
cur = conn.cursor()
cur.execute("""CREATE TABLE public.products
(
    report_number character varying(255) COLLATE pg_catalog."default",
    product_role character varying(255) COLLATE pg_catalog."default",
    product_name_brand character varying(255) COLLATE pg_catalog."default",
    product_industry_code character(255) COLLATE pg_catalog."default",
    product_industry_name character varying(255) COLLATE pg_catalog."default"
)
""")
conn.commit()

# %% [markdown]
# ## <font color=blue>-- 6f. Postgre SQL: Data deposit - "outcomes" table </font>

# %%
# 6f. Postgre SQL: Data deposit - "outcomes" table

# Error: CONTEXT:  COPY outcomes, line 8845: ""16,213",Other Outcome
# Solution: went in through EXCEL to re-format the column for numbers WITHOUT the comma

import psycopg2
conn = psycopg2.connect("host=localhost dbname=fda_food_events user=postgres password = Liam2007!")
cur = conn.cursor()
with open('outcomes_table.csv', 'r') as f:
    next(f) # Skip the header row.
    cur.copy_from(f, 'outcomes', sep=',')

conn.commit()

# %% [markdown]
# ## <font color=blue>-- 6g. Postgre SQL: Data deposit - "reactions" table </font>

# %%
# 6g. Postgre SQL: Data deposit - "reactions" table

# Error: CONTEXT:  COPY reactions, line 19592: ""16,213",VOMITING"
# Solution: went in through EXCEL to re-format the column for numbers WITHOUT the comma

import psycopg2
conn = psycopg2.connect("host=localhost dbname=fda_food_events user=postgres password = Liam2007!")
cur = conn.cursor()
with open('reactions_table.csv', 'r') as f:
    next(f) # Skip the header row.
    cur.copy_from(f, 'reactions', sep=',')

conn.commit()

# %% [markdown]
# ## <font color=blue>-- 6h. Postgre SQL: Data deposit - "consumer_report" table </font>

# %%
# 6h. Postgre SQL: Data deposit - "consumer_report" table

# Went into CSV file via EXCEL to re-format the column for numbers WITHOUT the comma
# age could not pull in nulls - so empty space replaced with 0
# date_started could not pull in null - so replaced with 19000101

import psycopg2
conn = psycopg2.connect("host=localhost dbname=fda_food_events user=postgres password = Liam2007!")
cur = conn.cursor()
with open('consumer_report_table.csv', 'r') as f:
    next(f) # Skip the header row.
    cur.copy_from(f, 'consumer_report', sep=',')

conn.commit()

# %% [markdown]
# ## <font color=blue>-- 6i. Postgre SQL: Data deposit - "products" table </font>

# %%
# 6i. Postgre SQL: Data deposit - "products" table

# Went into CSV file via EXCEL to re-format the column for numbers WITHOUT the comma
# Need to remove commas in product_names and industry_name
# EXEMPTION 4 has no industry_code (replaced with 0) or industry_name(replaced with 'not-reported')
# And then there were all the files where they added a new paragraph line to the name - manual clean - 16 reports

import psycopg2
conn = psycopg2.connect("host=localhost dbname=fda_food_events user=postgres password = Liam2007!")
cur = conn.cursor()
with open('products_table.csv', 'r') as f:
    next(f) # Skip the header row.
    cur.copy_from(f, 'products', sep=',')

conn.commit()

# %% [markdown]
# # <font color=red>7. SQL Queries</font>
# <font color=red>__-- a. SQL Query: Outcome of Death or Life Threatening - Report Count__<br>__-- b. SQL Query: Age (Where Reported) on Death or Life Threatening Reports__<br>__-- c. SQL Query: Products on Death or Life Threatening Reports for 5 and Under__<br>__-- d. SQL Query: Baby Food-Related Products Found on Death or Life Threatening Reports for 5 and Under__<br>__-- e. SQL Query: Brands of Baby Food Products and Formula as Found on Death or Life Threatening Reports for 5 and Under__<br>

# %% [markdown]
# ## <font color=blue>-- 7a. SQL Query: Outcome of Death or Life Threatening - Report Count </font>

# %% [markdown]
# 7a. SQL Query: Outcome of Death or Life Threatening - Report Count
#
# SELECT COUNT(o.report_number) AS report_count,
# 	   o.outcome
# FROM outcomes AS o
# WHERE o.outcome = 'Death'
# 	  OR o.outcome = 'Life Threatening'
# GROUP BY o.outcome;

# %%
# 7a. SQL Query: Outcome of Death or Life Threatening - Report Count - Import

outcome_death_life_threat_count = pd.read_csv (r'../FDA_Proj_2/SQL/Output/Outcome_Death_Life_Threatening_Count.csv')
print (outcome_death_life_threat_count)

print('TOTAL REPORTED = ',sum(outcome_death_life_threat_count['reports']))
# Out:
#    reports           outcome
# 0     6027             Death
# 1     4178  Life Threatening
# TOTAL REPORTED =  10205

# %% [markdown]
# ## <font color=blue>-- 7b. SQL Query: Age (Where Reported) on Death or Life Threatening Reports </font>

# %% [markdown]
# 7b. SQL Query: Age (Where Reported) on Death or Life Threatening Reports
#
# SELECT COUNT(o.report_number) AS report_count,
# 	o.outcome,
# 	c.absolute_age AS reported_age
# FROM outcomes AS o
# 	JOIN consumer_report AS c
# 	ON c.report_number = o.report_number
# WHERE c.absolute_age != 0
# 	AND(o.outcome = 'Death'
# 	OR o.outcome = 'Life Threatening')
# GROUP BY o.outcome,
# 	c.absolute_age
# ORDER BY report_count DESC,
# 	reported_age;

# %%
age_outcome_death_life_threatening = pd.read_csv (r'../FDA_Proj_2/SQL/Output/Age_Outcome_Death_Life_Threatening.csv')
age_outcome_death_life_threatening = pd.DataFrame(age_outcome_death_life_threatening)

print('TOTAL REPORTED = ',sum(age_outcome_death_life_threatening['report_count']))
age_outcome_death_life_threatening
# Out:
# TOTAL REPORTED =  6406
#      report_count           outcome  reported_age
# 0             168             Death       70.0000
# 1             156             Death       60.0000
# 2             109             Death       65.0000
# 3             102             Death       57.0000
# 4              95             Death       64.0000
# 5              89             Death       50.0000
# 6              88             Death       58.0000
# 7              85             Death       55.0000
# 8              84             Death       63.0000
# 9              82             Death       59.0000
# 10             78             Death       80.0000
# 11             77             Death       56.0000
# 12             72             Death       61.0000
# 13             72             Death       66.0000
# 14             72             Death       67.0000
# 15             71             Death       53.0000
# 16             71             Death       71.0000
# ...

# %% [markdown]
# ## <font color=blue>-- 7c. SQL Query: Products on Death or Life Threatening Reports for 5 and Under</font>

# %% [markdown]
# 7c. SQL Query: Products on Death or Life Threatening Reports for 5 and Under
#
# SELECT COUNT(o.report_number) AS report_count,
# 	o.outcome,
# 	p.product_industry_name
# FROM outcomes AS o
# 	JOIN consumer_report AS c
# 	ON c.report_number = o.report_number
# 	JOIN products as p
# 	ON p.report_number = c.report_number
# WHERE c.absolute_age != 0
# 	AND c.absolute_age <= 5
# 	AND(o.outcome = 'Death'
# 	OR o.outcome = 'Life Threatening')
# GROUP BY o.outcome,
# 	p.product_industry_name
# ORDER BY product_industry_name,
# 	o.outcome;

# %%
under_6_death_life_threatening = pd.read_csv (r'../FDA_Proj_2/SQL/Output/Under6_Death_Life_Threatening.csv')
under_6_death_life_threatening = pd.DataFrame(under_6_death_life_threatening)

print('TOTAL REPORTED = ',sum(under_6_death_life_threatening['report_count']))

under_6_death_life_threatening
# Out:
# TOTAL REPORTED =  202
#     report_count           outcome  \
# 0              8             Death
# 1             25  Life Threatening
# 2             28  Life Threatening
# 3              1  Life Threatening
# 4              6  Life Threatening
# 5              9  Life Threatening
# 6              7  Life Threatening
# 7              2  Life Threatening
# 8              1             Death
# 9              6  Life Threatening
# 10             3             Death
# 11             7  Life Threatening
# 12             1  Life Threatening
# 13             8  Life Threatening
# 14             4  Life Threatening
# 15             1  Life Threatening
# 16             2  Life Threatening
# 17             4  Life Threatening
# 18             6  Life Threatening
# 19             1  Life Threatening
# 20             8  Life Threatening
# 21             2  Life Threatening
# 22             2             Death
# 23             2  Life Threatening
# 24             2             Death
# ...

# %% [markdown]
# ## <font color=blue>-- 7d. SQL Query: Baby Food-Related Products Found on Death or Life Threatening Reports for 5 and Under</font>

# %% [markdown]
# 7d. SQL Query: Baby Food-Related Products Found on Death or Life Threatening Reports for 5 and Under
#
# SELECT COUNT(o.report_number) AS report_count,
# 	o.outcome,
# 	p.product_industry_name
# FROM outcomes AS o
# 	JOIN consumer_report AS c
# 	ON c.report_number = o.report_number
# 	JOIN products as p
# 	ON p.report_number = c.report_number
# WHERE c.absolute_age != 0
# 	AND c.absolute_age <= 5
# 	AND(o.outcome = 'Death'
# 		OR o.outcome = 'Life Threatening')
# 	AND(p.product_industry_name = 'Baby Food Products'
# 	    OR p.product_industry_name = 'Formula- Form Unspecified'
# 	    OR p.product_industry_name = 'Formula Raw Material'
# 	    OR p.product_industry_name = 'Liquid Concentrate Formula'
# 	   	OR p.product_industry_name = 'Powder Formula')
# GROUP BY o.outcome,
# 	p.product_industry_name
# ORDER BY product_industry_name,
# 	o.outcome;

# %%
Baby_Food_Related_Death_Life_Threatening = pd.read_csv (r'../FDA_Proj_2/SQL/Output/Baby_Food_Related_Death_Life_Threatening.csv')
Baby_Food_Related_Death_Life_Threatening = pd.DataFrame(Baby_Food_Related_Death_Life_Threatening)

print('TOTAL REPORTED = ',sum(Baby_Food_Related_Death_Life_Threatening['report_count']))

Baby_Food_Related_Death_Life_Threatening
# Out:
# TOTAL REPORTED =  41
#    report_count           outcome       product_industry_name
# 0             8             Death          Baby Food Products
# 1            25  Life Threatening          Baby Food Products
# 2             1  Life Threatening   Formula- Form Unspecified
# 3             2  Life Threatening        Formula Raw Material
# 4             1  Life Threatening  Liquid Concentrate Formula
# 5             2             Death              Powder Formula
# 6             2  Life Threatening              Powder Formula

# %% [markdown]
# ## <font color=blue>-- 7e. SQL Query: Brands of Baby Food Products and Formula as Found on Death or Life Threatening Reports for 5 and Under</font>

# %% [markdown]
# 7e. SQL Query: Brands of Baby Food Products and Formula as Found on Death or Life Threatening Reports for 5 and Under
#
# SELECT COUNT(o.report_number) AS report_count,
# 	o.outcome,
# 	p.product_role,
# 	p.product_name_brand
# FROM outcomes AS o
# 	JOIN consumer_report AS c
# 	ON c.report_number = o.report_number
# 	JOIN products as p
# 	ON p.report_number = c.report_number
# WHERE c.absolute_age != 0
# 	AND c.absolute_age <= 5
# 	AND(o.outcome = 'Death'
# 		OR o.outcome = 'Life Threatening')
# 	AND(p.product_industry_name = 'Baby Food Products'
# 	    OR p.product_industry_name = 'Formula- Form Unspecified'
# 	    OR p.product_industry_name = 'Formula Raw Material'
# 	    OR p.product_industry_name = 'Liquid Concentrate Formula'
# 	   	OR p.product_industry_name = 'Powder Formula')
# GROUP BY o.outcome,
# 	p.product_role,
# 	p.product_name_brand
# ORDER BY o.outcome,
# 		p.product_role,
# 		p.product_name_brand;

# %%
Baby_Food_Brands_Death_Life_Threatening = pd.read_csv (r'../FDA_Proj_2/SQL/Output/Baby_Food_Brands_Death_Life_Threatening.csv')
Baby_Food_Brands_Death_Life_Threatening = pd.DataFrame(Baby_Food_Brands_Death_Life_Threatening)

print('TOTAL REPORTED = ',sum(Baby_Food_Brands_Death_Life_Threatening['report_count']))

Baby_Food_Brands_Death_Life_Threatening
# Out:
# TOTAL REPORTED =  41
#     report_count           outcome product_role  \
# 0              1             Death  CONCOMITANT
# 1              1             Death      SUSPECT
# 2              1             Death      SUSPECT
# 3              2             Death      SUSPECT
# 4              1             Death      SUSPECT
# 5              1             Death      SUSPECT
# 6              1             Death      SUSPECT
# 7              1             Death      SUSPECT
# 8              1             Death      SUSPECT
# 9              1  Life Threatening  CONCOMITANT
# 10             1  Life Threatening      SUSPECT
# 11             3  Life Threatening      SUSPECT
# 12             1  Life Threatening      SUSPECT
# 13             2  Life Threatening      SUSPECT
# 14             1  Life Threatening      SUSPECT
# 15             1  Life Threatening      SUSPECT
# 16             1  Life Threatening      SUSPECT
# 17             1  Life Threatening      SUSPECT
# ...
